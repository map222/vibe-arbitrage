# %% [markdown]
# # Prompting via API

# %%
import os
from dotenv import load_dotenv
from utils import run_prompt

load_dotenv()
# Out:
# True

# %%
df = run_prompt("gg_picture", os.environ["GEMINI_API_KEY"], "gemini-3-flash-preview")
df
# Out:
# Columns OK
#      year     status              award                       title
# 0    2024     Winner              Drama                 Oppenheimer
# 1    2024  Nominated              Drama           Anatomy of a Fall
# 2    2024  Nominated              Drama  Killers of the Flower Moon
# 3    2024  Nominated              Drama                     Maestro
# 4    2024  Nominated              Drama                  Past Lives
# ..    ...        ...                ...                         ...
# 249  2000     Winner  Musical or Comedy                 Toy Story 2
# 250  2000  Nominated  Musical or Comedy                Analyze This
# 251  2000  Nominated  Musical or Comedy        Being John Malkovich
# 252  2000  Nominated  Musical or Comedy             Man on the Moon
# 253  2000  Nominated  Musical or Comedy                Notting Hill
#
# [254 rows x 4 columns]
